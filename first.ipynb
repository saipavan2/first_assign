# %%
import pandas as pd
import matplotlib.pyplot as plt

d=pd.read_csv('/content/drive/MyDrive/Shill Bidding Dataset.csv')

# %%
print(d)

# %%
print(d.isna())
print(d.isnull())

# %%
print(d[4:9])

# %%
x=d['Auction_Bids']
y=d['Auction_Duration']

# %%
plt.xlabel("auction")
plt.ylabel("duration")
plt.plot(x,y)

# %%
plt.plot(x,y)
